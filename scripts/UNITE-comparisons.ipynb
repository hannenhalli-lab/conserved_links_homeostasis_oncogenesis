# %%
source("./piyush_enrichment_functions.R")
# Out:
# Loading required package: pacman
#
# Warning message:
# “The `category` argument of `msigdbr()` is deprecated as of msigdbr 10.0.0.
# ℹ Please use the `collection` argument instead.”
# Warning message:
# “The `subcategory` argument of `msigdbr()` is deprecated as of msigdbr 10.0.0.
# ℹ Please use the `subcollection` argument instead.”
# [1] "###################################"
# [1] "Total inflam Signature: 10361"
# [1] "inflam Signature Union: 4782"
# [1] "inflam Signature Recurrent: 2120"
# [1] "###################################"
# [1] "Total Stress Signature: 11177"
# [1] "Stress Signature Union: 5384"
# [1] "Stress Signature Recurrent: 2036"
# [1] "Stress Signature Unique: 115"
# [1] "###################################"
# [1] "Total Wound Signature: 2415"
# [1] "Wound Signature Union: 1032"
# [1] "Wound Signature Recurrent: 517"
# [1] "Wound Healing Signature Unique: 30"
# [1] "###################################"
# [1] "Total Regen Signature: 665"
# ...

# %%
library("wesanderson")

# %%
frac_files <- list.files("../data/for_my_analysis/", "gs.*Frac.RDS")
gs_ratios <- list()
gs_labels <- list()
for(i in 1:length(frac_files)) {
    curr_frac_gs <- readRDS(paste0("../data/",frac_files[i]))
    name <- gsub("(gs_high_|\\Frac.RDS)","",frac_files[i])
    gs_ratios[[name]] <- curr_frac_gs
    gs_labels[[name]] <- rep(name,length(curr_frac_gs))
    
}

frac_files_high <- list.files("../data/for_my_analysis/", "high_low.*Frac.RDS")
high_ratios <- list()
high_labels <- list()
for(i in 1:length(frac_files_high)) {
    curr_frac_high <- readRDS(paste0("../data/",frac_files_high[i]))
    name <- gsub("(high_low_|\\Frac.RDS)","",frac_files_high[i])
    high_ratios[[name]] <- curr_frac_high
    high_labels[[name]] <- rep(name,length(curr_frac_high))
    
}

# %%
options(repr.plot.width=18, repr.plot.height=14)

# %%
gs_df <- data.frame("label"= unlist(gs_labels),
                    "ratio" = 1/unlist(gs_ratios))
plot <- ggplot(gs_df, aes(y=ratio,x=label,fill= label)) +
geom_boxplot()  +
scale_y_continuous(limits=c(0,7)) +
geom_hline(aes(yintercept=1), colour="red") +
theme_minimal()+
scale_fill_manual(values = wes_palette("FantasticFox1",
                                       n = 7,type = "continuous"),
                  name = "Categories")+ 
theme(text = element_text(size=20),
          legend.position="none") +
scale_x_discrete(labels=c("DEG",
                          "DEG-up",
                          "DEG-down",
                          "DepMap",
                          "HR-Pos",
                          "HR-Neg",
                          "Mutation Frequency"))+
labs(title="UNITe-High vs. Goldset across modalities",x="", y = "Ratio of UNITe-High vs. Goldset across Cancer Types")

print(plot)
# add another boxplot for HR protective and hazardous
# flip

# Save the figure
#ggsave("~/Desktop/Figure4D_UNITe_vs_Goldset.pdf", plot = plot, width = 15, height = 8)
# Out:
# Error in ggplot(gs_df, aes(y = ratio, x = label, fill = label)): could not find function "ggplot"
# Traceback:

# %%
high_df <- data.frame("label"= unlist(high_labels),
                    "ratio" = unlist(high_ratios))
plot <- ggplot(high_df, aes(y=ratio,x=label,fill= label)) +
geom_boxplot()  +
scale_y_continuous(limits=c(0,3)) +
geom_hline(aes(yintercept=1), colour="red") +
theme_minimal()+
scale_fill_manual(values = wes_palette("FantasticFox1",
                                       n = 7,type = "continuous"),
                  name = "Categories")+ 
theme(text = element_text(size=20),
          legend.position="none") +
scale_x_discrete(labels=c("DEG",
                          "DEG-up",
                          "DEG-down",
                          "DepMap",
                          "HR-Pos",
                          "HR-Neg",
                          "Mutation Frequency"))+
labs(title="UNITe-High vs. UNITe-Low across modalities",x="", y = "Ratio of UNITe-High vs. UNITe-Low across Cancer Types")

print(plot)

# Save the figure
ggsave("~/Desktop/Figure4D_UNITeHigh_vs_UNITeLow.pdf", plot = plot, width = 15, height = 10)
# Out:
# Error in ggplot(high_df, aes(y = ratio, x = label, fill = label)): could not find function "ggplot"
# Traceback:
